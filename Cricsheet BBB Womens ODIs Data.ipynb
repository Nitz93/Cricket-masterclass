# %% [markdown]
# ## Imports

# %%
import pandas as pd
import glob

# %% [markdown]
# ## Check for any errors

# %%
ls1 = glob.glob("t20s_female_csv2\*.csv")
ls2 = []

for i in ls1:
    try:
        ls2.append(pd.read_csv(i))
    except:
        print('error', i)
# Out:
# error t20s_female_csv2\1043989_info.csv
# error t20s_female_csv2\1043991_info.csv
# error t20s_female_csv2\1043993_info.csv
# error t20s_female_csv2\1044211_info.csv
# error t20s_female_csv2\1050615_info.csv
# error t20s_female_csv2\1065348_info.csv
# error t20s_female_csv2\1086067_info.csv
# error t20s_female_csv2\1086068_info.csv
# error t20s_female_csv2\1086069_info.csv
# error t20s_female_csv2\1122902_info.csv
# error t20s_female_csv2\1122908_info.csv
# error t20s_female_csv2\1122909_info.csv
# error t20s_female_csv2\1122910_info.csv
# error t20s_female_csv2\1123206_info.csv
# error t20s_female_csv2\1123207_info.csv
# error t20s_female_csv2\1123208_info.csv
# error t20s_female_csv2\1123209_info.csv
# error t20s_female_csv2\1123210_info.csv
# error t20s_female_csv2\1126720_info.csv
# error t20s_female_csv2\1126721_info.csv
# error t20s_female_csv2\1126722_info.csv
# error t20s_female_csv2\1126723_info.csv
# error t20s_female_csv2\1126724_info.csv
# ...

# %% [markdown]
# ## Combine Match by Match CSV files

# %%
#importing multiple files in a directory
l = [pd.read_csv(filename) if "_info" not in filename else print(filename) for filename in glob.glob("t20s_female_csv2\*.csv")]
df = pd.concat(l, axis = 0)
# Out:
# t20s_female_csv2\1043989_info.csv
# t20s_female_csv2\1043991_info.csv
# t20s_female_csv2\1043993_info.csv
# t20s_female_csv2\1044211_info.csv
# t20s_female_csv2\1050615_info.csv
# t20s_female_csv2\1065348_info.csv
# t20s_female_csv2\1086067_info.csv
# t20s_female_csv2\1086068_info.csv
# t20s_female_csv2\1086069_info.csv
# t20s_female_csv2\1122902_info.csv
# t20s_female_csv2\1122908_info.csv
# t20s_female_csv2\1122909_info.csv
# t20s_female_csv2\1122910_info.csv
# t20s_female_csv2\1123206_info.csv
# t20s_female_csv2\1123207_info.csv
# t20s_female_csv2\1123208_info.csv
# t20s_female_csv2\1123209_info.csv
# t20s_female_csv2\1123210_info.csv
# t20s_female_csv2\1126720_info.csv
# t20s_female_csv2\1126721_info.csv
# t20s_female_csv2\1126722_info.csv
# t20s_female_csv2\1126723_info.csv
# t20s_female_csv2\1126724_info.csv
# t20s_female_csv2\1126725_info.csv
# t20s_female_csv2\1126726_info.csv
# t20s_female_csv2\1131235_info.csv
# t20s_female_csv2\1131236_info.csv
# ...

# %% [markdown]
# ## Sneak peak

# %%
df.tail()
# Out:
#      match_id season  start_date                              venue  innings  \
# 117    962023   2016  2016-09-05  Bready Cricket Club, Magheramason        2
# 118    962023   2016  2016-09-05  Bready Cricket Club, Magheramason        2
# 119    962023   2016  2016-09-05  Bready Cricket Club, Magheramason        2
# 120    962023   2016  2016-09-05  Bready Cricket Club, Magheramason        2
# 121    962023   2016  2016-09-05  Bready Cricket Club, Magheramason        2
#
#      ball batting_team bowling_team        striker    non_striker  ... extras  \
# 117   9.2   Bangladesh      Ireland   Rumana Ahmed  Fargana Hoque  ...      0
# 118   9.3   Bangladesh      Ireland      Ritu Moni  Fargana Hoque  ...      0
# 119   9.4   Bangladesh      Ireland  Fargana Hoque  Fahima Khatun  ...      0
# 120   9.5   Bangladesh      Ireland  Jahanara Alam  Fahima Khatun  ...      0
# 121   9.6   Bangladesh      Ireland  Jahanara Alam  Fahima Khatun  ...      0
#
# ...

# %% [markdown]
# ## Sort by dates

# %%
df['start_date'] = pd.to_datetime(df['start_date'])

# %%
df = df.sort_values('start_date', ascending = True)

# %% [markdown]
# ## Check after sorting

# %%
df.tail()
# Out:
#      match_id   season start_date                         venue  innings  \
# 148   1289031  2021/22 2022-02-09  John Davies Oval, Queenstown        2
# 147   1289031  2021/22 2022-02-09  John Davies Oval, Queenstown        2
# 146   1289031  2021/22 2022-02-09  John Davies Oval, Queenstown        2
# 161   1289031  2021/22 2022-02-09  John Davies Oval, Queenstown        2
# 220   1289031  2021/22 2022-02-09  John Davies Oval, Queenstown        2
#
#      ball batting_team bowling_team        striker    non_striker  ... extras  \
# 148   4.4        India  New Zealand      YH Bhatia  Shafali Verma  ...      0
# 147   4.3        India  New Zealand      YH Bhatia  Shafali Verma  ...      0
# 146   4.2        India  New Zealand      YH Bhatia  Shafali Verma  ...      0
# 161   6.5        India  New Zealand  Shafali Verma         H Kaur  ...      0
# 220  16.2        India  New Zealand      Sneh Rana    P Vastrakar  ...      0
#
# ...

# %%
len(df)
# Out:
# 133034

# %% [markdown]
# ## Check for duplicates

# %%
len(df)-len(df.drop_duplicates())
# Out:
# 4

# %%
df.drop_duplicates(inplace=True)
df.reset_index(inplace=True, drop=True)

# %% [markdown]
# ## Export to single CSV

# %%
df.to_csv('Womens_T20I_ball_by_ball_updated.csv', index = False)
